# %% [markdown]
# ### Feature Extraction
# - pkl을 로드해서 사용하는 부분 next_batch에 추가하기 (given이 true이면 하고 아니면 원래대로 하는 것으로)
# - 한 노래 돌때 피쳐 모두 뽑아서 각각 저장하기

# %%
import os
import numpy as np
import pandas as pd
import features
from scipy import stats
import librosa
from tqdm import *
import pickle

# %%
def test(feature_name, split_method, is_save=False, HOP_LENGTH=None, N_FFT=None, N_CHROMA=None, N_BANDS=None):
    if is_save:
        return save_output_as_pkl(
            output = get_tid_feature_pairs(
                    get_track_ids(
                        split_df(
                            build_metadata_df('dataset/track_metadata.csv')
                            , split_method
                        )
                    )
                    , feature_name
                    , HOP_LENGTH
                    , N_FFT
                    , N_CHROMA
                    , N_BANDS
                )
            , filename='{}_{}.pkl'.format(feature_name, split_method)
        )
    else:
        return get_tid_feature_pairs(
                    get_track_ids(
                        split_df(
                            build_metadata_df('dataset/track_metadata.csv')
                            , split_method
                        )
                    )
                    , feature_name
                    , HOP_LENGTH
                    , N_FFT
                    , N_CHROMA
                    , N_BANDS
                )

def build_metadata_df(filepath):
    return pd.read_csv(filepath)

def split_df(metadata_df, split_method):
    return metadata_df[metadata_df['set_split'] == split_method]

def get_track_ids(metadata_df):
    return metadata_df['track_id'].values

def save_output_as_pkl(output, filename):
    with open(filename, 'wb') as f:
        pickle.dump(output, f)

test('chroma_stft', 'training', is_save=True, HOP_LENGTH=512*8, N_FFT=2048, N_CHROMA=20)
test('chroma_stft', 'validation', is_save=True, HOP_LENGTH=512*8, N_FFT=2048, N_CHROMA=20)
#print(test('rmse', 'training', HOP_LENGTH=512*8, N_FFT=2048)[0][1].shape)
#print(test('spectral_contrast', 'training', HOP_LENGTH=512*8, N_BANDS=6)[0][1].shape)
#test('rmse', 'training')
#test('rmse', 'validation')
#test('spectral_contrast', 'training')
#test('spectral_contrast', 'validation')

# TODO : dictionary 로 track_id : array로 받아서 나중에 array로 바꾸는게 낫지 않을까? 현재는 일단 그냥 함.
# TODO : get_feature_by_tid로 바꾸기
# Out:
# /Users/dongmin.shin/anaconda3/lib/python3.6/site-packages/librosa/core/pitch.py:145: UserWarning: Trying to estimate tuning from empty frequency set.
#   warnings.warn('Trying to estimate tuning from empty frequency set.')
# 139491: ValueError('song length is shorter than threshold',)
# 139520: FileNotFoundError(2, 'No such file or directory')
# 139521: FileNotFoundError(2, 'No such file or directory')
# 139522: FileNotFoundError(2, 'No such file or directory')
# 139523: FileNotFoundError(2, 'No such file or directory')
# 139524: FileNotFoundError(2, 'No such file or directory')
# 139532: FileNotFoundError(2, 'No such file or directory')
# 139534: FileNotFoundError(2, 'No such file or directory')
# 139536: FileNotFoundError(2, 'No such file or directory')
# 139537: FileNotFoundError(2, 'No such file or directory')
# 139637: FileNotFoundError(2, 'No such file or directory')
# 139638: FileNotFoundError(2, 'No such file or directory')
# 139663: FileNotFoundError(2, 'No such file or directory')
# 139681: FileNotFoundError(2, 'No such file or directory')
# 139687: FileNotFoundError(2, 'No such file or directory')
# 139688: FileNotFoundError(2, 'No such file or directory')
# 139769: FileNotFoundError(2, 'No such file or directory')
# 139770: FileNotFoundError(2, 'No such file or directory')
# 139771: FileNotFoundError(2, 'No such file or directory')
# 139772: FileNotFoundError(2, 'No such file or directory')
# 139773: FileNotFoundError(2, 'No such file or directory')
# 139774: FileNotFoundError(2, 'No such file or directory')
# 139775: FileNotFoundError(2, 'No such file or directory')
# 139776: FileNotFoundError(2, 'No such file or directory')
# 139777: FileNotFoundError(2, 'No such file or directory')
# 139804: FileNotFoundError(2, 'No such file or directory')
# 139862: FileNotFoundError(2, 'No such file or directory')
# 139876: FileNotFoundError(2, 'No such file or directory')
# 139954: FileNotFoundError(2, 'No such file or directory')
# 139990: FileNotFoundError(2, 'No such file or directory')
# 139991: FileNotFoundError(2, 'No such file or directory')
# 139992: FileNotFoundError(2, 'No such file or directory')
# 139993: FileNotFoundError(2, 'No such file or directory')
# 139994: FileNotFoundError(2, 'No such file or directory')
# 139995: FileNotFoundError(2, 'No such file or directory')
# 140134: FileNotFoundError(2, 'No such file or directory')
# 140135: FileNotFoundError(2, 'No such file or directory')
# 140258: FileNotFoundError(2, 'No such file or directory')
# 140259: FileNotFoundError(2, 'No such file or directory')
# 140260: FileNotFoundError(2, 'No such file or directory')
# 140261: FileNotFoundError(2, 'No such file or directory')
# 140262: FileNotFoundError(2, 'No such file or directory')
# 140263: FileNotFoundError(2, 'No such file or directory')
# 140266: FileNotFoundError(2, 'No such file or directory')
# 140316: FileNotFoundError(2, 'No such file or directory')
# 140344: FileNotFoundError(2, 'No such file or directory')
# 140421: FileNotFoundError(2, 'No such file or directory')
# 140564: FileNotFoundError(2, 'No such file or directory')
# 140565: FileNotFoundError(2, 'No such file or directory')
# 140566: FileNotFoundError(2, 'No such file or directory')
# 140576: FileNotFoundError(2, 'No such file or directory')
# 140584: FileNotFoundError(2, 'No such file or directory')
# 140788: FileNotFoundError(2, 'No such file or directory')
# 140789: FileNotFoundError(2, 'No such file or directory')
# 140790: FileNotFoundError(2, 'No such file or directory')
# 140791: FileNotFoundError(2, 'No such file or directory')
# 140794: FileNotFoundError(2, 'No such file or directory')
# 140871: FileNotFoundError(2, 'No such file or directory')
# 140872: FileNotFoundError(2, 'No such file or directory')
# 140873: FileNotFoundError(2, 'No such file or directory')
# 140874: FileNotFoundError(2, 'No such file or directory')
# 140875: FileNotFoundError(2, 'No such file or directory')
# 141074: FileNotFoundError(2, 'No such file or directory')
# 141137: FileNotFoundError(2, 'No such file or directory')
# 141139: FileNotFoundError(2, 'No such file or directory')
# 141141: FileNotFoundError(2, 'No such file or directory')
# 141143: FileNotFoundError(2, 'No such file or directory')
# 141144: FileNotFoundError(2, 'No such file or directory')
# 141164: FileNotFoundError(2, 'No such file or directory')
# 141166: FileNotFoundError(2, 'No such file or directory')
# 141167: FileNotFoundError(2, 'No such file or directory')
# 141168: FileNotFoundError(2, 'No such file or directory')
# 141173: FileNotFoundError(2, 'No such file or directory')
# 141179: FileNotFoundError(2, 'No such file or directory')
# 141180: FileNotFoundError(2, 'No such file or directory')
# 141181: FileNotFoundError(2, 'No such file or directory')
# 141182: FileNotFoundError(2, 'No such file or directory')
# 141264: FileNotFoundError(2, 'No such file or directory')
# 141282: FileNotFoundError(2, 'No such file or directory')
# 141283: FileNotFoundError(2, 'No such file or directory')
# 141284: FileNotFoundError(2, 'No such file or directory')
# 141285: FileNotFoundError(2, 'No such file or directory')
# 141286: FileNotFoundError(2, 'No such file or directory')
# 141287: FileNotFoundError(2, 'No such file or directory')
# 141288: FileNotFoundError(2, 'No such file or directory')
# 141289: FileNotFoundError(2, 'No such file or directory')
# 141290: FileNotFoundError(2, 'No such file or directory')
# 141291: FileNotFoundError(2, 'No such file or directory')
# 141292: FileNotFoundError(2, 'No such file or directory')
# 141293: FileNotFoundError(2, 'No such file or directory')
# 141295: FileNotFoundError(2, 'No such file or directory')
# 141296: FileNotFoundError(2, 'No such file or directory')
# 141297: FileNotFoundError(2, 'No such file or directory')
# 141299: FileNotFoundError(2, 'No such file or directory')
# 141300: FileNotFoundError(2, 'No such file or directory')
# 141303: FileNotFoundError(2, 'No such file or directory')
# 141304: FileNotFoundError(2, 'No such file or directory')
# 141310: FileNotFoundError(2, 'No such file or directory')
# 141375: FileNotFoundError(2, 'No such file or directory')
# 141561: FileNotFoundError(2, 'No such file or directory')
# 141562: FileNotFoundError(2, 'No such file or directory')
# 141564: FileNotFoundError(2, 'No such file or directory')
# 141566: FileNotFoundError(2, 'No such file or directory')
# 141567: FileNotFoundError(2, 'No such file or directory')
# 141568: FileNotFoundError(2, 'No such file or directory')
# 141569: FileNotFoundError(2, 'No such file or directory')
# 141590: FileNotFoundError(2, 'No such file or directory')
# 141591: FileNotFoundError(2, 'No such file or directory')
# 141592: FileNotFoundError(2, 'No such file or directory')
# 141593: FileNotFoundError(2, 'No such file or directory')
# 141594: FileNotFoundError(2, 'No such file or directory')
# 141873: FileNotFoundError(2, 'No such file or directory')
# 141874: FileNotFoundError(2, 'No such file or directory')
# 141875: FileNotFoundError(2, 'No such file or directory')
# 141876: FileNotFoundError(2, 'No such file or directory')
# 141894: FileNotFoundError(2, 'No such file or directory')
# 141901: FileNotFoundError(2, 'No such file or directory')
# 141902: FileNotFoundError(2, 'No such file or directory')
# 141903: FileNotFoundError(2, 'No such file or directory')
# 141972: FileNotFoundError(2, 'No such file or directory')
# 142078: FileNotFoundError(2, 'No such file or directory')
# 142079: FileNotFoundError(2, 'No such file or directory')
# 142080: FileNotFoundError(2, 'No such file or directory')
# 142081: FileNotFoundError(2, 'No such file or directory')
# 142082: FileNotFoundError(2, 'No such file or directory')
# 142083: FileNotFoundError(2, 'No such file or directory')
# 142084: FileNotFoundError(2, 'No such file or directory')
# 142085: FileNotFoundError(2, 'No such file or directory')
# 142086: FileNotFoundError(2, 'No such file or directory')
# 142087: FileNotFoundError(2, 'No such file or directory')
# 142088: FileNotFoundError(2, 'No such file or directory')
# 142089: FileNotFoundError(2, 'No such file or directory')
# 142091: FileNotFoundError(2, 'No such file or directory')
# 142092: FileNotFoundError(2, 'No such file or directory')
# 142093: FileNotFoundError(2, 'No such file or directory')
# 142128: FileNotFoundError(2, 'No such file or directory')
# 142129: FileNotFoundError(2, 'No such file or directory')
# 142132: FileNotFoundError(2, 'No such file or directory')
# 142133: FileNotFoundError(2, 'No such file or directory')
# 142381: FileNotFoundError(2, 'No such file or directory')
# 142402: FileNotFoundError(2, 'No such file or directory')
# 142418: FileNotFoundError(2, 'No such file or directory')
# 142511: FileNotFoundError(2, 'No such file or directory')
# 142516: FileNotFoundError(2, 'No such file or directory')
# 142517: FileNotFoundError(2, 'No such file or directory')
# 142519: FileNotFoundError(2, 'No such file or directory')
# 142528: FileNotFoundError(2, 'No such file or directory')
# 142529: FileNotFoundError(2, 'No such file or directory')
# 142530: FileNotFoundError(2, 'No such file or directory')
# 142531: FileNotFoundError(2, 'No such file or directory')
# 142532: FileNotFoundError(2, 'No such file or directory')
# 142549: FileNotFoundError(2, 'No such file or directory')
# 142550: FileNotFoundError(2, 'No such file or directory')
# 142551: FileNotFoundError(2, 'No such file or directory')
# 142552: FileNotFoundError(2, 'No such file or directory')
# 142553: FileNotFoundError(2, 'No such file or directory')
# 142564: FileNotFoundError(2, 'No such file or directory')
# 142565: FileNotFoundError(2, 'No such file or directory')
# 142566: FileNotFoundError(2, 'No such file or directory')
# 142567: FileNotFoundError(2, 'No such file or directory')
# 142568: FileNotFoundError(2, 'No such file or directory')
# 142569: FileNotFoundError(2, 'No such file or directory')
# 142570: FileNotFoundError(2, 'No such file or directory')
# 142571: FileNotFoundError(2, 'No such file or directory')
# 142572: FileNotFoundError(2, 'No such file or directory')
# 142573: FileNotFoundError(2, 'No such file or directory')
# 142574: FileNotFoundError(2, 'No such file or directory')
# 142575: FileNotFoundError(2, 'No such file or directory')
# 142576: FileNotFoundError(2, 'No such file or directory')
# 142577: FileNotFoundError(2, 'No such file or directory')
# 142579: FileNotFoundError(2, 'No such file or directory')
# 142666: FileNotFoundError(2, 'No such file or directory')
# 142668: FileNotFoundError(2, 'No such file or directory')
# 142669: FileNotFoundError(2, 'No such file or directory')
# 142670: FileNotFoundError(2, 'No such file or directory')
# 142671: FileNotFoundError(2, 'No such file or directory')
# 142672: FileNotFoundError(2, 'No such file or directory')
# 143039: FileNotFoundError(2, 'No such file or directory')
# 143046: FileNotFoundError(2, 'No such file or directory')
# 143055: FileNotFoundError(2, 'No such file or directory')
# 143056: FileNotFoundError(2, 'No such file or directory')
# 143057: FileNotFoundError(2, 'No such file or directory')
# 143058: FileNotFoundError(2, 'No such file or directory')
# 143059: FileNotFoundError(2, 'No such file or directory')
# 143060: FileNotFoundError(2, 'No such file or directory')
# 143061: FileNotFoundError(2, 'No such file or directory')
# 143095: FileNotFoundError(2, 'No such file or directory')
# 143097: FileNotFoundError(2, 'No such file or directory')
# 143098: FileNotFoundError(2, 'No such file or directory')
# 143099: FileNotFoundError(2, 'No such file or directory')
# 143106: FileNotFoundError(2, 'No such file or directory')
# 143214: FileNotFoundError(2, 'No such file or directory')
# 143215: FileNotFoundError(2, 'No such file or directory')
# 143216: FileNotFoundError(2, 'No such file or directory')
# 143217: FileNotFoundError(2, 'No such file or directory')
# 143218: FileNotFoundError(2, 'No such file or directory')
# 143219: FileNotFoundError(2, 'No such file or directory')
# 143220: FileNotFoundError(2, 'No such file or directory')
# 143221: FileNotFoundError(2, 'No such file or directory')
# 143237: FileNotFoundError(2, 'No such file or directory')
# 143290: FileNotFoundError(2, 'No such file or directory')
# 143318: FileNotFoundError(2, 'No such file or directory')
# 143319: FileNotFoundError(2, 'No such file or directory')
# 143532: FileNotFoundError(2, 'No such file or directory')
# 143989: FileNotFoundError(2, 'No such file or directory')
# 143995: FileNotFoundError(2, 'No such file or directory')
# 144170: FileNotFoundError(2, 'No such file or directory')
# 144171: FileNotFoundError(2, 'No such file or directory')
# 144172: FileNotFoundError(2, 'No such file or directory')
# 144173: FileNotFoundError(2, 'No such file or directory')
# 144179: FileNotFoundError(2, 'No such file or directory')
# 144180: FileNotFoundError(2, 'No such file or directory')
# 144181: FileNotFoundError(2, 'No such file or directory')
# 144182: FileNotFoundError(2, 'No such file or directory')
# 144423: FileNotFoundError(2, 'No such file or directory')
# 144424: FileNotFoundError(2, 'No such file or directory')
# 144465: FileNotFoundError(2, 'No such file or directory')
# 144466: FileNotFoundError(2, 'No such file or directory')
# 144467: FileNotFoundError(2, 'No such file or directory')
# 144468: FileNotFoundError(2, 'No such file or directory')
# 144469: FileNotFoundError(2, 'No such file or directory')
# 144470: FileNotFoundError(2, 'No such file or directory')
# 144471: FileNotFoundError(2, 'No such file or directory')
# 144472: FileNotFoundError(2, 'No such file or directory')
# 144473: FileNotFoundError(2, 'No such file or directory')
# 144474: FileNotFoundError(2, 'No such file or directory')
# 144475: FileNotFoundError(2, 'No such file or directory')
# 144476: FileNotFoundError(2, 'No such file or directory')
# 144477: FileNotFoundError(2, 'No such file or directory')
# 144487: FileNotFoundError(2, 'No such file or directory')
# 144492: FileNotFoundError(2, 'No such file or directory')
# 144542: FileNotFoundError(2, 'No such file or directory')
# 144543: FileNotFoundError(2, 'No such file or directory')
# 144544: FileNotFoundError(2, 'No such file or directory')
# 144545: FileNotFoundError(2, 'No such file or directory')
# 144546: FileNotFoundError(2, 'No such file or directory')
# 144547: FileNotFoundError(2, 'No such file or directory')
# 144548: FileNotFoundError(2, 'No such file or directory')
# 144549: FileNotFoundError(2, 'No such file or directory')
# 144550: FileNotFoundError(2, 'No such file or directory')
# 144551: FileNotFoundError(2, 'No such file or directory')
# 144552: FileNotFoundError(2, 'No such file or directory')
# 144587: FileNotFoundError(2, 'No such file or directory')
# 144733: FileNotFoundError(2, 'No such file or directory')
# 144740: FileNotFoundError(2, 'No such file or directory')
# 144741: FileNotFoundError(2, 'No such file or directory')
# 144809: FileNotFoundError(2, 'No such file or directory')
# 144810: FileNotFoundError(2, 'No such file or directory')
# 144933: FileNotFoundError(2, 'No such file or directory')
# 144934: FileNotFoundError(2, 'No such file or directory')
# 144935: FileNotFoundError(2, 'No such file or directory')
# 144936: FileNotFoundError(2, 'No such file or directory')
# 144937: FileNotFoundError(2, 'No such file or directory')
# 144938: FileNotFoundError(2, 'No such file or directory')
# 144939: FileNotFoundError(2, 'No such file or directory')
# 144940: FileNotFoundError(2, 'No such file or directory')
# 144941: FileNotFoundError(2, 'No such file or directory')
# 144942: FileNotFoundError(2, 'No such file or directory')
# 144943: FileNotFoundError(2, 'No such file or directory')
# 144944: FileNotFoundError(2, 'No such file or directory')
# 144945: FileNotFoundError(2, 'No such file or directory')
# 144946: FileNotFoundError(2, 'No such file or directory')
# 145002: FileNotFoundError(2, 'No such file or directory')
# 145003: FileNotFoundError(2, 'No such file or directory')
# 145004: FileNotFoundError(2, 'No such file or directory')
# 145005: FileNotFoundError(2, 'No such file or directory')
# 145020: FileNotFoundError(2, 'No such file or directory')
# 145027: FileNotFoundError(2, 'No such file or directory')
# 145041: FileNotFoundError(2, 'No such file or directory')
# 145042: FileNotFoundError(2, 'No such file or directory')
# 145043: FileNotFoundError(2, 'No such file or directory')
# 145058: FileNotFoundError(2, 'No such file or directory')
# 145059: FileNotFoundError(2, 'No such file or directory')
# 145074: FileNotFoundError(2, 'No such file or directory')
# 145183: FileNotFoundError(2, 'No such file or directory')
# 145189: FileNotFoundError(2, 'No such file or directory')
# 145199: FileNotFoundError(2, 'No such file or directory')
# 145241: FileNotFoundError(2, 'No such file or directory')
# 145257: FileNotFoundError(2, 'No such file or directory')
# 145258: FileNotFoundError(2, 'No such file or directory')
# 145259: FileNotFoundError(2, 'No such file or directory')
# 145260: FileNotFoundError(2, 'No such file or directory')
# 145431: FileNotFoundError(2, 'No such file or directory')
# 145432: FileNotFoundError(2, 'No such file or directory')
# 145462: FileNotFoundError(2, 'No such file or directory')
# 145464: FileNotFoundError(2, 'No such file or directory')
# 145550: FileNotFoundError(2, 'No such file or directory')
# 145551: FileNotFoundError(2, 'No such file or directory')
# 145552: FileNotFoundError(2, 'No such file or directory')
# 145553: FileNotFoundError(2, 'No such file or directory')
# 145554: FileNotFoundError(2, 'No such file or directory')
# 145555: FileNotFoundError(2, 'No such file or directory')
# 145556: FileNotFoundError(2, 'No such file or directory')
# 145606: FileNotFoundError(2, 'No such file or directory')
# 145607: FileNotFoundError(2, 'No such file or directory')
# 145608: FileNotFoundError(2, 'No such file or directory')
# 145609: FileNotFoundError(2, 'No such file or directory')
# 145610: FileNotFoundError(2, 'No such file or directory')
# 145645: FileNotFoundError(2, 'No such file or directory')
# 145646: FileNotFoundError(2, 'No such file or directory')
# 145653: FileNotFoundError(2, 'No such file or directory')
# 145702: FileNotFoundError(2, 'No such file or directory')
# 145703: FileNotFoundError(2, 'No such file or directory')
# 145704: FileNotFoundError(2, 'No such file or directory')
# 145705: FileNotFoundError(2, 'No such file or directory')
# 145706: FileNotFoundError(2, 'No such file or directory')
# 145707: FileNotFoundError(2, 'No such file or directory')
# 145708: FileNotFoundError(2, 'No such file or directory')
# 145709: FileNotFoundError(2, 'No such file or directory')
# 145710: FileNotFoundError(2, 'No such file or directory')
# 145711: FileNotFoundError(2, 'No such file or directory')
# 145724: FileNotFoundError(2, 'No such file or directory')
# 145727: FileNotFoundError(2, 'No such file or directory')
# 145728: FileNotFoundError(2, 'No such file or directory')
# 145729: FileNotFoundError(2, 'No such file or directory')
# 145730: FileNotFoundError(2, 'No such file or directory')
# 145741: FileNotFoundError(2, 'No such file or directory')
# 145742: FileNotFoundError(2, 'No such file or directory')
# 145743: FileNotFoundError(2, 'No such file or directory')
# 145744: FileNotFoundError(2, 'No such file or directory')
# 145745: FileNotFoundError(2, 'No such file or directory')
# 145746: FileNotFoundError(2, 'No such file or directory')
# 145752: FileNotFoundError(2, 'No such file or directory')
# 145754: FileNotFoundError(2, 'No such file or directory')
# 145755: FileNotFoundError(2, 'No such file or directory')
# 145756: FileNotFoundError(2, 'No such file or directory')
# 145757: FileNotFoundError(2, 'No such file or directory')
# 145758: FileNotFoundError(2, 'No such file or directory')
# 145759: FileNotFoundError(2, 'No such file or directory')
# 145760: FileNotFoundError(2, 'No such file or directory')
# 145761: FileNotFoundError(2, 'No such file or directory')
# 145780: FileNotFoundError(2, 'No such file or directory')
# 145783: FileNotFoundError(2, 'No such file or directory')
# 145917: FileNotFoundError(2, 'No such file or directory')
# 145918: FileNotFoundError(2, 'No such file or directory')
# 146017: FileNotFoundError(2, 'No such file or directory')
# 146018: FileNotFoundError(2, 'No such file or directory')
# 146019: FileNotFoundError(2, 'No such file or directory')
# 146020: FileNotFoundError(2, 'No such file or directory')
# 146070: FileNotFoundError(2, 'No such file or directory')
# 146147: FileNotFoundError(2, 'No such file or directory')
# 146148: FileNotFoundError(2, 'No such file or directory')
# 146149: FileNotFoundError(2, 'No such file or directory')
# 146150: FileNotFoundError(2, 'No such file or directory')
# 146151: FileNotFoundError(2, 'No such file or directory')
# 146152: FileNotFoundError(2, 'No such file or directory')
# 146153: FileNotFoundError(2, 'No such file or directory')
# 146458: FileNotFoundError(2, 'No such file or directory')
# 146478: FileNotFoundError(2, 'No such file or directory')
# 146481: FileNotFoundError(2, 'No such file or directory')
# 146482: FileNotFoundError(2, 'No such file or directory')
# 146483: FileNotFoundError(2, 'No such file or directory')
# 146639: FileNotFoundError(2, 'No such file or directory')
# 146681: FileNotFoundError(2, 'No such file or directory')
# 146683: FileNotFoundError(2, 'No such file or directory')
# 146685: FileNotFoundError(2, 'No such file or directory')
# 146687: FileNotFoundError(2, 'No such file or directory')
# 146689: FileNotFoundError(2, 'No such file or directory')
# 146713: FileNotFoundError(2, 'No such file or directory')
# 146716: FileNotFoundError(2, 'No such file or directory')
# 146724: FileNotFoundError(2, 'No such file or directory')
# 146725: FileNotFoundError(2, 'No such file or directory')
# 146726: FileNotFoundError(2, 'No such file or directory')
# 146727: FileNotFoundError(2, 'No such file or directory')
# 146961: FileNotFoundError(2, 'No such file or directory')
# 146968: FileNotFoundError(2, 'No such file or directory')
# 146969: FileNotFoundError(2, 'No such file or directory')
# 146970: FileNotFoundError(2, 'No such file or directory')
# 147059: FileNotFoundError(2, 'No such file or directory')
# 147085: FileNotFoundError(2, 'No such file or directory')
# 147086: FileNotFoundError(2, 'No such file or directory')
# 147087: FileNotFoundError(2, 'No such file or directory')
# 147126: FileNotFoundError(2, 'No such file or directory')
# 147191: FileNotFoundError(2, 'No such file or directory')
# 147265: FileNotFoundError(2, 'No such file or directory')
# 147267: FileNotFoundError(2, 'No such file or directory')
# 147268: FileNotFoundError(2, 'No such file or directory')
# 147269: FileNotFoundError(2, 'No such file or directory')
# 147295: FileNotFoundError(2, 'No such file or directory')
# 147309: FileNotFoundError(2, 'No such file or directory')
# 147409: FileNotFoundError(2, 'No such file or directory')
# 147412: FileNotFoundError(2, 'No such file or directory')
# 147413: FileNotFoundError(2, 'No such file or directory')
# 147780: FileNotFoundError(2, 'No such file or directory')
# 147815: FileNotFoundError(2, 'No such file or directory')
# 147886: FileNotFoundError(2, 'No such file or directory')
# 147956: FileNotFoundError(2, 'No such file or directory')
# 148066: FileNotFoundError(2, 'No such file or directory')
# 148070: FileNotFoundError(2, 'No such file or directory')
# 148074: FileNotFoundError(2, 'No such file or directory')
# 148075: FileNotFoundError(2, 'No such file or directory')
# 148076: FileNotFoundError(2, 'No such file or directory')
# 148077: FileNotFoundError(2, 'No such file or directory')
# 148078: FileNotFoundError(2, 'No such file or directory')
# 148079: FileNotFoundError(2, 'No such file or directory')
# 148099: FileNotFoundError(2, 'No such file or directory')
# 148112: FileNotFoundError(2, 'No such file or directory')
# 148113: FileNotFoundError(2, 'No such file or directory')
# 148114: FileNotFoundError(2, 'No such file or directory')
# 148120: FileNotFoundError(2, 'No such file or directory')
# 148121: FileNotFoundError(2, 'No such file or directory')
# 148124: FileNotFoundError(2, 'No such file or directory')
# 148130: FileNotFoundError(2, 'No such file or directory')
# 148131: FileNotFoundError(2, 'No such file or directory')
# 148132: FileNotFoundError(2, 'No such file or directory')
# 148133: FileNotFoundError(2, 'No such file or directory')
# 148168: FileNotFoundError(2, 'No such file or directory')
# 148246: FileNotFoundError(2, 'No such file or directory')
# 148285: FileNotFoundError(2, 'No such file or directory')
# 148286: FileNotFoundError(2, 'No such file or directory')
# 148287: FileNotFoundError(2, 'No such file or directory')
# 148288: FileNotFoundError(2, 'No such file or directory')
# 148289: FileNotFoundError(2, 'No such file or directory')
# 148290: FileNotFoundError(2, 'No such file or directory')
# 148302: FileNotFoundError(2, 'No such file or directory')
# 148305: FileNotFoundError(2, 'No such file or directory')
# 148439: FileNotFoundError(2, 'No such file or directory')
# 148441: FileNotFoundError(2, 'No such file or directory')
# 148443: FileNotFoundError(2, 'No such file or directory')
# 148444: FileNotFoundError(2, 'No such file or directory')
# 148510: FileNotFoundError(2, 'No such file or directory')
# 148513: FileNotFoundError(2, 'No such file or directory')
# 148514: FileNotFoundError(2, 'No such file or directory')
# 148516: FileNotFoundError(2, 'No such file or directory')
# 148517: FileNotFoundError(2, 'No such file or directory')
# 148518: FileNotFoundError(2, 'No such file or directory')
# 148519: FileNotFoundError(2, 'No such file or directory')
# 148532: FileNotFoundError(2, 'No such file or directory')
# 148535: FileNotFoundError(2, 'No such file or directory')
# 148536: FileNotFoundError(2, 'No such file or directory')
# 148537: FileNotFoundError(2, 'No such file or directory')
# 148584: FileNotFoundError(2, 'No such file or directory')
# 148585: FileNotFoundError(2, 'No such file or directory')
# 148586: FileNotFoundError(2, 'No such file or directory')
# 148587: FileNotFoundError(2, 'No such file or directory')
# 148602: FileNotFoundError(2, 'No such file or directory')
# 148603: FileNotFoundError(2, 'No such file or directory')
# 148604: FileNotFoundError(2, 'No such file or directory')
# 148605: FileNotFoundError(2, 'No such file or directory')
# 148773: FileNotFoundError(2, 'No such file or directory')
# 149075: FileNotFoundError(2, 'No such file or directory')
# 149078: FileNotFoundError(2, 'No such file or directory')
# 149082: FileNotFoundError(2, 'No such file or directory')
# 149083: FileNotFoundError(2, 'No such file or directory')
# 149099: FileNotFoundError(2, 'No such file or directory')
# 149100: FileNotFoundError(2, 'No such file or directory')
# 149101: FileNotFoundError(2, 'No such file or directory')
# 149102: FileNotFoundError(2, 'No such file or directory')
# 149103: FileNotFoundError(2, 'No such file or directory')
# 149118: FileNotFoundError(2, 'No such file or directory')
# 149124: FileNotFoundError(2, 'No such file or directory')
# 149138: FileNotFoundError(2, 'No such file or directory')
# 149139: FileNotFoundError(2, 'No such file or directory')
# 149140: FileNotFoundError(2, 'No such file or directory')
# 149141: FileNotFoundError(2, 'No such file or directory')
# 149142: FileNotFoundError(2, 'No such file or directory')
# 149143: FileNotFoundError(2, 'No such file or directory')
# 149185: FileNotFoundError(2, 'No such file or directory')
# 149369: FileNotFoundError(2, 'No such file or directory')
# 149370: FileNotFoundError(2, 'No such file or directory')
# 149416: FileNotFoundError(2, 'No such file or directory')
# 149417: FileNotFoundError(2, 'No such file or directory')
# 149422: FileNotFoundError(2, 'No such file or directory')
# 149488: FileNotFoundError(2, 'No such file or directory')
# 149523: FileNotFoundError(2, 'No such file or directory')
# 149687: FileNotFoundError(2, 'No such file or directory')
# 149689: FileNotFoundError(2, 'No such file or directory')
# 149690: FileNotFoundError(2, 'No such file or directory')
# 149700: FileNotFoundError(2, 'No such file or directory')
# 149701: FileNotFoundError(2, 'No such file or directory')
# 149712: FileNotFoundError(2, 'No such file or directory')
# 149714: FileNotFoundError(2, 'No such file or directory')
# 149727: FileNotFoundError(2, 'No such file or directory')
# 149750: FileNotFoundError(2, 'No such file or directory')
# 149775: FileNotFoundError(2, 'No such file or directory')
# 149776: FileNotFoundError(2, 'No such file or directory')
# 149777: FileNotFoundError(2, 'No such file or directory')
# 149778: FileNotFoundError(2, 'No such file or directory')
# 149842: FileNotFoundError(2, 'No such file or directory')
# 149951: FileNotFoundError(2, 'No such file or directory')
# 149953: FileNotFoundError(2, 'No such file or directory')
# 150062: FileNotFoundError(2, 'No such file or directory')
# 150063: FileNotFoundError(2, 'No such file or directory')
# 150064: FileNotFoundError(2, 'No such file or directory')
# 150073: FileNotFoundError(2, 'No such file or directory')
# 150078: FileNotFoundError(2, 'No such file or directory')
# 150079: FileNotFoundError(2, 'No such file or directory')
# 150080: FileNotFoundError(2, 'No such file or directory')
# 150265: FileNotFoundError(2, 'No such file or directory')
# 150266: FileNotFoundError(2, 'No such file or directory')
# 150267: FileNotFoundError(2, 'No such file or directory')
# 150268: FileNotFoundError(2, 'No such file or directory')
# 151404: FileNotFoundError(2, 'No such file or directory')
# 152103: FileNotFoundError(2, 'No such file or directory')
# 152253: FileNotFoundError(2, 'No such file or directory')
# 152254: FileNotFoundError(2, 'No such file or directory')
# 152258: FileNotFoundError(2, 'No such file or directory')
# 152261: FileNotFoundError(2, 'No such file or directory')
# 152262: FileNotFoundError(2, 'No such file or directory')
# 152324: FileNotFoundError(2, 'No such file or directory')
# 152418: FileNotFoundError(2, 'No such file or directory')
# 152425: FileNotFoundError(2, 'No such file or directory')
# 152480: FileNotFoundError(2, 'No such file or directory')
# 152543: FileNotFoundError(2, 'No such file or directory')
# 152545: FileNotFoundError(2, 'No such file or directory')
# 152568: FileNotFoundError(2, 'No such file or directory')
# 152569: FileNotFoundError(2, 'No such file or directory')
# 152570: FileNotFoundError(2, 'No such file or directory')
# 153337: FileNotFoundError(2, 'No such file or directory')
# 153383: FileNotFoundError(2, 'No such file or directory')
# 153452: FileNotFoundError(2, 'No such file or directory')
# 153946: FileNotFoundError(2, 'No such file or directory')
# 153955: FileNotFoundError(2, 'No such file or directory')
# 153956: FileNotFoundError(2, 'No such file or directory')
# 154413: FileNotFoundError(2, 'No such file or directory')
# 154414: FileNotFoundError(2, 'No such file or directory')
# 155066: FileNotFoundError(2, 'No such file or directory')
# 140583: FileNotFoundError(2, 'No such file or directory')
# 140935: FileNotFoundError(2, 'No such file or directory')
# 140939: FileNotFoundError(2, 'No such file or directory')
# 141735: FileNotFoundError(2, 'No such file or directory')
# 142094: FileNotFoundError(2, 'No such file or directory')
# 142096: FileNotFoundError(2, 'No such file or directory')
# 142097: FileNotFoundError(2, 'No such file or directory')
# 142098: FileNotFoundError(2, 'No such file or directory')
# 142433: FileNotFoundError(2, 'No such file or directory')
# 142563: FileNotFoundError(2, 'No such file or directory')
# 142641: FileNotFoundError(2, 'No such file or directory')
# 142947: FileNotFoundError(2, 'No such file or directory')
# 142948: FileNotFoundError(2, 'No such file or directory')
# 142949: FileNotFoundError(2, 'No such file or directory')
# 142950: FileNotFoundError(2, 'No such file or directory')
# 143186: FileNotFoundError(2, 'No such file or directory')
# 143239: FileNotFoundError(2, 'No such file or directory')
# 143295: FileNotFoundError(2, 'No such file or directory')
# 143296: FileNotFoundError(2, 'No such file or directory')
# 143299: FileNotFoundError(2, 'No such file or directory')
# 143300: FileNotFoundError(2, 'No such file or directory')
# 143303: FileNotFoundError(2, 'No such file or directory')
# 143304: FileNotFoundError(2, 'No such file or directory')
# 143305: FileNotFoundError(2, 'No such file or directory')
# 143306: FileNotFoundError(2, 'No such file or directory')
# 143307: FileNotFoundError(2, 'No such file or directory')
# 143308: FileNotFoundError(2, 'No such file or directory')
# 143309: FileNotFoundError(2, 'No such file or directory')
# 143941: FileNotFoundError(2, 'No such file or directory')
# 144454: FileNotFoundError(2, 'No such file or directory')
# 144600: FileNotFoundError(2, 'No such file or directory')
# 144801: FileNotFoundError(2, 'No such file or directory')
# 145549: FileNotFoundError(2, 'No such file or directory')
# 146343: FileNotFoundError(2, 'No such file or directory')
# 146879: FileNotFoundError(2, 'No such file or directory')
# 146988: FileNotFoundError(2, 'No such file or directory')
# 146989: FileNotFoundError(2, 'No such file or directory')
# 148186: FileNotFoundError(2, 'No such file or directory')
# 148187: FileNotFoundError(2, 'No such file or directory')
# 148190: FileNotFoundError(2, 'No such file or directory')
# 148208: FileNotFoundError(2, 'No such file or directory')
# 148210: FileNotFoundError(2, 'No such file or directory')
# 148211: FileNotFoundError(2, 'No such file or directory')
# 148212: FileNotFoundError(2, 'No such file or directory')
# 148213: FileNotFoundError(2, 'No such file or directory')
# 148214: FileNotFoundError(2, 'No such file or directory')
# 148215: FileNotFoundError(2, 'No such file or directory')
# 148216: FileNotFoundError(2, 'No such file or directory')
# 148217: FileNotFoundError(2, 'No such file or directory')
# 148218: FileNotFoundError(2, 'No such file or directory')
# 148231: FileNotFoundError(2, 'No such file or directory')
# 148233: FileNotFoundError(2, 'No such file or directory')
# 148234: FileNotFoundError(2, 'No such file or directory')
# 148235: FileNotFoundError(2, 'No such file or directory')
# 148303: FileNotFoundError(2, 'No such file or directory')
# 148429: FileNotFoundError(2, 'No such file or directory')
# 149452: FileNotFoundError(2, 'No such file or directory')

# %%
def get_tid_feature_pairs(tids, feature_name, HOP_LENGTH, N_FFT, N_CHROMA, N_BANDS):
    tid_feature_pairs = list()
    
    for tid in tqdm_notebook(tids):
        try:
            x, sr = load_audio_as_librosa_format(
                get_audio_path('music/music_training', tid)
                , DURATION=29.0
            )
            
            tid_feature_pairs.append((
                tid
                , np.array( 
                     compute_feature(
                         tid,
                         cut_x(x.tolist(), THRESHOLD=1278900)
                         , feature_name
                         , HOP_LENGTH
                         , N_FFT
                         , N_CHROMA
                         , N_BANDS
                     )
                )
            ))
        except Exception as e:
            print('{}: {}'.format(tid, repr(e)))

    return tid_feature_pairs

def get_audio_path(audio_dir, track_id):
    tid_str = '{:06d}'.format(track_id)
    return os.path.join(audio_dir, tid_str[:3], tid_str + '.mp3')

def load_audio_as_librosa_format(filepath, DURATION):
    return librosa.load(filepath, sr=None, mono=True, duration=DURATION)  # kaiser_fast

def cut_x(x, THRESHOLD):
    validate_x(x, THRESHOLD)
    return np.array(x[:THRESHOLD])

def validate_x(x, THRESHOLD):
    try:
        assert len(x) >= THRESHOLD
    except:
        raise ValueError('song length is shorter than threshold')
        
def compute_feature(tid, cutted_x, feature_name, HOP_LENGTH, N_FFT, N_CHROMA, N_BANDS):
    if feature_name == 'chroma_stft':
        feature = compute_chroma_stft(
            compute_stft(cutted_x, N_FFT, HOP_LENGTH)
            , N_CHROMA
        ).tolist()

    if feature_name == 'rmse':
        feature = compute_rmse(
            compute_stft(cutted_x, N_FFT, HOP_LENGTH)
        ).tolist()

    if feature_name == 'spectral_contrast':
        feature = compute_spectral_contrast(
            compute_stft(cutted_x, N_FFT, HOP_LENGTH)
            , N_BANDS
        ).tolist()
    return validate_feature(tid, feature)
    
def validate_feature(tid, feature):
    try:
        assert feature != 0
        return feature
    except:
        raise ValueError('tid {} has feature error'.format(tid))
    
def compute_stft(x, N_FFT, HOP_LENGTH):
    stft = np.abs(librosa.stft(x, n_fft=N_FFT, hop_length=HOP_LENGTH))
    return validate_stft(stft, x, N_FFT, HOP_LENGTH)

def validate_stft(stft, x, N_FFT, HOP_LENGTH):
    assert stft.shape[0] == 1 + N_FFT // 2
    assert np.ceil(len(x) / HOP_LENGTH) \
        <= stft.shape[1] \
        <= np.ceil(len(x) / HOP_LENGTH) + 1
    return stft

def compute_chroma_stft(stft, N_CHROMA):
    return librosa.feature.chroma_stft(S=stft ** 2, n_chroma=N_CHROMA) 
        
def compute_rmse(stft):
    return librosa.feature.rmse(S=stft)

def compute_spectral_contrast(stft, N_BANDS):
    print(N_BANDS)
    return librosa.feature.spectral_contrast(S=stft, n_bands=N_BANDS)
